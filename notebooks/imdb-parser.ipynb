# %%
from pymdb import Movie, MovieId

# %%
m = Movie("The Shawshank Redemption")
m.info()
# Out:
# The Shawshank Redemption
# Year:  1994
# Rating: 9.3 (1,886,223 votes)
# Metascore:  80
# Language:  English
# Genre:  Crime, Drama
# Director:  Frank Darabont
# Awards:  Nominated for 7 Oscars. Another 19 wins & 29 nominations.

# %%
m = MovieId("tt0111161")

# %%
m.info()
# Out:
# The Shawshank Redemption
# Year:  1994
# Rating: 9.3 (1,886,223 votes)
# Metascore:  80
# Language:  English
# Genre:  Crime, Drama
# Director:  Frank Darabont
# Awards:  Nominated for 7 Oscars. Another 19 wins & 29 nominations.

# %%
#m.reviews()
print("http://www.imdb.com/title/%s/reviews?ref_=tt_ov_rt" % m.stuff["imdbID"])
# Out:
# http://www.imdb.com/title/tt0111161/reviews?ref_=tt_ov_rt

# %%
from imdb import IMDb

ia = IMDb()

# %%
s_result = ia.search_movie('The Untouchables')

for item in s_result:
   print(item['long imdb canonical title'], item.movieID)

the_unt = s_result[0]
ia.update(the_unt)
# Out:
# Upside, The (2017) 1987680
# Untouchables, The (1987) 0094226
# "Untouchables, The" (1959) 0052522
# "Untouchables, The" (1993) 0106165
# "Daughters of Destiny" (2017) 1877895
# Machine Gun McCain (1969) 0065895
# Untouchables: Capone Rising (in development), The (None) 0425602
# Scarface Mob, The (1959) (TV) 0056449
# Untouchable (2011) 2000439
# Intouchables, The (2011) 1675434
# Untouchable, The (2006) 0810077
# Untouchable (I) (2016) 5509634
# "Untouchable" (II) (2017) 7598556
# Untouchable, The (1997) (VG) 0287779
# "Untouchable" (2015) 4191792
# Untouchable 2, The (2001) (VG) 0287778
# Untouchable  (in development) (II) (None) 5220680
# Untouchable, The (2017) 7332436
# "Harbour Lights" The Untouchables (1999) 0596815
# "Professionals, The" The Untouchables (1983) 0679343

# %%
the_unt.keys()
# Out:
# ['plot',
#  'akas',
#  'year',
#  'kind',
#  'title',
#  'canonical title',
#  'long imdb title',
#  'long imdb canonical title',
#  'smart canonical title',
#  'smart long imdb canonical title']

# %%
print(the_unt['title'])
# Out:
# The leading information resource for the entertainment industry

# %%
the_matrix = ia.get_movie('0133092')

# %%
print(the_matrix['plot'])
# Out:
# ['Billy is kidnapped and held for ransom. Agent Wingate of the FBI is assigned to recover him.::TheMovieSmith']

# %%
print(the_matrix.get('external_reviews'))
# Out:
# None

# %%
ia.update(the_matrix, 'reviews')

# %%
the_matrix.keys()
# Out:
# ['title',
#  'plot',
#  'kind',
#  'canonical title',
#  'long imdb title',
#  'long imdb canonical title',
#  'smart canonical title',
#  'smart long imdb canonical title']

# %%
from tqdm import tqdm
start = 133093

all_reviews = []
for i in tqdm(range(133093, 2527336)):
    string_id = '{:04d}'.format(i)
    movie = ia.get_movie(string_id)
    
    if 'reviews' in movie.keys():
        all_reviews.append(string_id)
        print(string_id)
# Out:
#   0%|          | 34/2394243 [02:04<2436:52:40,  3.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-bf37ae844a4e> in <module>()
#       5 for i in tqdm(range(133093, 2527336)):
#       6     string_id = '{:04d}'.format(i)
# ----> 7     movie = ia.get_movie(string_id)
#       8
#       9     if 'reviews' in movie.keys():
#
# ~/.virtualenvs/neural-review-summarization/lib/python3.5/site-packages/imdb/__init__.py in get_movie(self, movieID, info, modFunct)
#     396         if modFunct is not None:
#     397             movie.set_mod_funct(modFunct)
# --> 398         self.update(movie, info)
#     399         return movie
#     400
#
# ~/.virtualenvs/neural-review-summarization/lib/python3.5/site-packages/imdb/__init__.py in update(self, mop, info, override)
#     704                 method = lambda *x: {}
#     705             try:
# --> 706                 ret = method(mopID)
#     707             except Exception:
#     708                 _imdb_logger.critical(
#
# ~/.virtualenvs/neural-review-summarization/lib/python3.5/site-packages/imdb/parser/http/__init__.py in get_movie_main(self, movieID)
#     430
#     431     def get_movie_main(self, movieID):
# --> 432         cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#     433         return self.mProxy.movie_parser.parse(cont, mdparse=self._mdparse)
#     434
#
# ~/.virtualenvs/neural-review-summarization/lib/python3.5/site-packages/imdb/parser/http/__init__.py in _retrieve(self, url, size, _noCookies)
#     392         self._http_logger.debug('fetching url %s (size: %d)', url, size)
#     393         try:
# --> 394             ret = self.urlOpener.retrieve_unicode(url, size=size)
#     395         finally:
#     396             if _noCookies and _cookies:
#
# ~/.virtualenvs/neural-review-summarization/lib/python3.5/site-packages/imdb/parser/http/__init__.py in retrieve_unicode(self, url, size)
#     175             uopener = self.open(url)
#     176             kwds = {}
# --> 177             content = uopener.read(**kwds)
#     178             self._last_url = uopener.url
#     179             # Maybe the server is so nice to tell us the charset...
#
# ~/.virtualenvs/neural-review-summarization/lib/python3.5/tempfile.py in func_wrapper(*args, **kwargs)
#     620             @_functools.wraps(func)
#     621             def func_wrapper(*args, **kwargs):
# --> 622                 return func(*args, **kwargs)
#     623             # Avoid closing the file as long as the wrapper is alive,
#     624             # see issue #18879.
#
# /usr/lib/python3.5/http/client.py in read(self, amt)
#     453
#     454             if self.chunked:
# --> 455                 return self._readall_chunked()
#     456
#     457             if self.length is None:
#
# /usr/lib/python3.5/http/client.py in _readall_chunked(self)
#     559                 if chunk_left is None:
#     560                     break
# --> 561                 value.append(self._safe_read(chunk_left))
#     562                 self.chunk_left = 0
#     563             return b''.join(value)
#
# /usr/lib/python3.5/http/client.py in _safe_read(self, amt)
#     605         s = []
#     606         while amt > 0:
# --> 607             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     608             if not chunk:
#     609                 raise IncompleteRead(b''.join(s), amt)
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
'title' in the_matrix.keys()
# Out:
# True

# %%
ia.get_movie_infoset()
# Out:
# ['airing',
#  'akas',
#  'alternate versions',
#  'awards',
#  'business',
#  'connections',
#  'crazy credits',
#  'critic reviews',
#  'episodes',
#  'episodes cast',
#  'episodes rating',
#  'external reviews',
#  'external sites',
#  'faqs',
#  'full credits',
#  'goofs',
#  'guests',
#  'keywords',
#  'literature',
#  'locations',
#  'main',
#  'misc sites',
#  'news',
#  'official sites',
#  'parents guide',
#  'photo sites',
#  'plot',
#  'quotes',
#  'recommendations',
#  'release dates',
#  'release info',
#  'reviews',
#  'sound clips',
#  'soundtrack',
#  'synopsis',
#  'taglines',
#  'technical',
#  'trivia',
#  'tv schedule',
#  'video clips',
#  'vote details']
